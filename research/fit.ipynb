# %% [markdown]
# ## Данные

# %%
import numpy as np
import pandas as pd

# %%
import os
train_pos_names = os.listdir('./../movie_reviews/aclImdb/train/pos')
train_neg_names = os.listdir('./../movie_reviews/aclImdb/train/neg')
test_pos_names = os.listdir('./../movie_reviews/aclImdb/test/pos')
test_neg_names = os.listdir('./../movie_reviews/aclImdb/test/neg')

# %%
y_train = [int(s.split('_')[1].split('.')[0]) for s in train_pos_names] + \
          [int(s.split('_')[1].split('.')[0]) for s in train_neg_names]
    
y_test = [int(s.split('_')[1].split('.')[0]) for s in test_pos_names] + \
          [int(s.split('_')[1].split('.')[0]) for s in test_neg_names]

# %%
train = []
test = []

for name in train_pos_names:
    with open('./../movie_reviews/aclImdb/train/pos/' + name) as f:
        train.append(f.read())
        
for name in train_neg_names:
    with open('./../movie_reviews/aclImdb/train/neg/' + name) as f:
        train.append(f.read())
        
for name in test_pos_names:
    with open('./../movie_reviews/aclImdb/test/pos/' + name) as f:
        test.append(f.read())
        
for name in test_neg_names:
    with open('./../movie_reviews/aclImdb/test/neg/' + name) as f:
        test.append(f.read())

# %%
from pytorch_transformers import BertTokenizer, BertConfig


tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

token_train = [tokenizer.tokenize(sent) for sent in train]
token_test = [tokenizer.tokenize(sent) for sent in test]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

train_input_ids = [tokenizer.convert_tokens_to_ids(x) for x in token_train]
train_input_ids = pad_sequences(
    train_input_ids,
    maxlen=100,
    dtype="long",
    truncating="post",
    padding="post"
)
train_attention_masks = [[float(i>0) for i in seq] for seq in train_input_ids]
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0625 21:26:52.808473 140385315886912 tokenization_utils.py:665] Token indices sequence length is longer than the specified maximum sequence length for this model (682 > 512). Running this sequence through the model will result in indexing errors
# W0625 21:26:52.810602 140385315886912 tokenization_utils.py:665] Token indices sequence length is longer than the specified maximum sequence length for this model (829 > 512). Running this sequence through the model will result in indexing errors
# W0625 21:26:52.812453 140385315886912 tokenization_utils.py:665] Token indices sequence length is longer than the specified maximum sequence length for this model (857 > 512). Running this sequence through the model will result in indexing errors
# ...

# %%
test_input_ids = [tokenizer.convert_tokens_to_ids(x) for x in token_train]
test_input_ids = pad_sequences(
    test_input_ids,
    maxlen=100,
    dtype="long",
    truncating="post",
    padding="post"
)
test_attention_masks = [[float(i>0) for i in seq] for seq in test_input_ids]
# Out:
# W0625 21:27:02.229031 140385315886912 tokenization_utils.py:665] Token indices sequence length is longer than the specified maximum sequence length for this model (682 > 512). Running this sequence through the model will result in indexing errors
# W0625 21:27:02.231780 140385315886912 tokenization_utils.py:665] Token indices sequence length is longer than the specified maximum sequence length for this model (829 > 512). Running this sequence through the model will result in indexing errors
# W0625 21:27:02.235184 140385315886912 tokenization_utils.py:665] Token indices sequence length is longer than the specified maximum sequence length for this model (857 > 512). Running this sequence through the model will result in indexing errors
# W0625 21:27:02.236584 140385315886912 tokenization_utils.py:665] Token indices sequence length is longer than the specified maximum sequence length for this model (585 > 512). Running this sequence through the model will result in indexing errors
# ...

# %%
import torch

train_inputs = torch.tensor(train_input_ids)
train_labels = torch.tensor(y_train)
train_masks = torch.tensor(train_attention_masks)

test_inputs = torch.tensor(test_input_ids)
test_labels = torch.tensor(y_test)
test_masks = torch.tensor(test_attention_masks)

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_dataloader = DataLoader(
    train_data,
    sampler=RandomSampler(train_data),
    batch_size=32
)

test_data = TensorDataset(test_inputs, test_masks, test_labels)
test_dataloader = DataLoader(
    test_data,
    sampler=RandomSampler(test_data),
    batch_size=32
)

# %% [markdown]
# ## Модель

# %%
from pytorch_transformers import BertForMultipleChoice, BertForSequenceClassification

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=8)
# Out:
#   0%|          | 0/440473133 [00:00<?, ?B/s]
#
#
#
#   0%|          | 17408/440473133 [00:00<1:22:06, 89408.14B/s]
#
#
#
#   0%|          | 52224/440473133 [00:00<1:06:25, 110511.48B/s]
#
#
#
#   0%|          | 120832/440473133 [00:00<51:48, 141662.47B/s]
#
#
#
#   0%|          | 156672/440473133 [00:01<1:14:00, 99165.06B/s]
#
#
#
#   0%|          | 365568/440473133 [00:01<53:56, 135961.86B/s]
#
#
#
#   0%|          | 406528/440473133 [00:01<49:04, 149465.69B/s]
#
#
#
#   0%|          | 441344/440473133 [00:01<59:53, 122455.14B/s]
#
#
#
#   0%|          | 504832/440473133 [00:02<48:56, 149844.89B/s]
#
#
#
#   0%|          | 609280/440473133 [00:02<38:37, 189835.92B/s]
#
#
#
#   0%|          | 644096/440473133 [00:02<44:30, 164689.74B/s]
#
#
#
#   0%|          | 696320/440473133 [00:02<40:56, 179003.91B/s]
#
#
#
#   0%|          | 748544/440473133 [00:03<37:20, 196265.42B/s]
#
#
#
#   0%|          | 800768/440473133 [00:03<34:40, 211293.45B/s]
#
#
#
# ...
